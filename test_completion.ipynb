# %%
# Generate a python code that sum elements in an array 
def sum_elements_array(array):
    # Doing the sum over a loop 
    result = 0
    for x in array: 
        result += x 
    return result 

# Getting the maximum element from an array 
def get_maximum_elements_array(array):
    maximum = array[0]
    for value in array:
        if value>maximum:
            max

# %%
def maximum_element_array(array):
